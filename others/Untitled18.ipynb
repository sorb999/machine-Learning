# %%
run svm.py
# Out:
# > f:\ml\project git hub\machinelearning\others\svm.py(4)<module>()
# -> digits = datasets.load_digits()
# (Pdb) n
# > f:\ml\project git hub\machinelearning\others\svm.py(5)<module>()
# -> X_digits = digits.data
# (Pdb) n
# > f:\ml\project git hub\machinelearning\others\svm.py(6)<module>()
# -> y_digits = digits.target
# (Pdb) X_digits
# array([[  0.,   0.,   5., ...,   0.,   0.,   0.],
#        [  0.,   0.,   0., ...,  10.,   0.,   0.],
#        [  0.,   0.,   0., ...,  16.,   9.,   0.],
#        ...,
#        [  0.,   0.,   1., ...,   6.,   0.,   0.],
#        [  0.,   0.,   2., ...,  12.,   0.,   0.],
#        [  0.,   0.,  10., ...,  12.,   1.,   0.]])
# (Pdb) digits
# {'data': array([[  0.,   0.,   5., ...,   0.,   0.,   0.],
#        [  0.,   0.,   0., ...,  10.,   0.,   0.],
#        [  0.,   0.,   0., ...,  16.,   9.,   0.],
#        ...,
#        [  0.,   0.,   1., ...,   6.,   0.,   0.],
#        [  0.,   0.,   2., ...,  12.,   0.,   0.],
# ...
